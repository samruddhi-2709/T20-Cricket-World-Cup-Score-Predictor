# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []
for file in os.listdir('data'):
    filenames.append(os.path.join('data',file))

# %%
filenames[0:5]
# Out:
# ['data/1173055.yaml',
#  'data/951375.yaml',
#  'data/1188621.yaml',
#  'data/540173.yaml',
#  'data/1034829.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
#  48%|███████████████████▎                    | 690/1433 [01:56<02:38,  4.68it/s]

# %%
backup = final_df.copy()

# %%
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 0   [{'1st innings': {'team': 'India', 'deliveries...                0.9
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 0   [{'1st innings': {'team': 'India', 'deliveries...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
#
#    meta.created  meta.revision   info.city    info.dates info.gender  \
# 0    2020-03-01              1    Canberra  [2020-02-26]      female
# 0    2016-03-17              2   Bangalore  [2016-03-15]      female
# 0    2019-08-06              1  Lauderhill  [2019-08-03]        male
# 0    2012-04-16              2    St Lucia  [2012-03-27]        male
# 0    2017-02-13              1   Bangalore  [2017-02-01]        male
# ..          ...            ...         ...           ...         ...
# 0    2017-02-17              1         NaN  [2017-02-17]      female
# 0    2012-04-16              2    Auckland  [2012-02-11]        male
# 0    2017-04-02              1    Trinidad  [2017-04-01]        male
# 0    2016-03-08              1      Nagpur  [2016-03-08]        male
# 0    2009-11-13              3         NaN  [2009-11-12]        male
#
#    info.match_type  info.match_type_number info.outcome.winner  ...  \
# 0              T20                   853.0            Pakistan  ...
# 0              T20                     NaN               India  ...
# 0              T20                   842.0               India  ...
# 0              T20                     NaN           Australia  ...
# 0              T20                     NaN               India  ...
# ..             ...                     ...                 ...  ...
# 0              T20                     NaN           Australia  ...
# 0              T20                     NaN         New Zealand  ...
# 0              T20                     NaN         West Indies  ...
# 0              T20                     NaN         Afghanistan  ...
# 0              T20                     NaN            Pakistan  ...
#
#                       info.umpires  \
# 0           [CA Polosak, S George]
# 0       [Aleem Dar, REJ Martinesz]
# 0        [N Duguid, GO Brathwaite]
# 0         [GO Brathwaite, PJ Nero]
# 0      [AK Chaudhary, Nitin Menon]
# ..                             ...
# 0            [GA Abood, SAJ Craig]
# 0           [GAV Baxter, BG Frost]
# 0       [GO Brathwaite, LS Reifer]
# 0      [M Erasmus, RK Illingworth]
# 0   [Nadeem Ghauri, Zameer Haider]
#
#                                            info.venue match_id  \
# 0                                         Manuka Oval        1
# 0                               M Chinnaswamy Stadium        2
# 0   Central Broward Regional Park Stadium Turf Ground        3
# 0                      Beausejour Stadium, Gros Islet        4
# 0                               M Chinnaswamy Stadium        5
# ..                                                ...      ...
# 0                            Melbourne Cricket Ground     1070
# 0                                           Eden Park     1071
# 0                    Queen's Park Oval, Port of Spain     1072
# 0        Vidarbha Cricket Association Stadium, Jamtha     1073
# 0                 Dubai International Cricket Stadium     1074
#
#    info.outcome.by.runs info.neutral_venue info.outcome.method  \
# 0                   NaN                NaN                 NaN
# 0                  72.0                NaN                 NaN
# 0                   NaN                NaN                 NaN
# 0                   NaN                NaN                 NaN
# 0                  75.0                NaN                 NaN
# ..                  ...                ...                 ...
# 0                  40.0                NaN                 NaN
# 0                   NaN                NaN                 NaN
# 0                   NaN                NaN                 NaN
# 0                  14.0                1.0                 NaN
# 0                  49.0                1.0                 NaN
#
#    info.outcome.result info.outcome.eliminator  info.bowl_out  \
# 0                  NaN                     NaN            NaN
# 0                  NaN                     NaN            NaN
# 0                  NaN                     NaN            NaN
# 0                  NaN                     NaN            NaN
# 0                  NaN                     NaN            NaN
# ..                 ...                     ...            ...
# 0                  NaN                     NaN            NaN
# 0                  NaN                     NaN            NaN
# 0                  NaN                     NaN            NaN
# 0                  NaN                     NaN            NaN
# 0                  NaN                     NaN            NaN
#
#     info.outcome.bowl_out
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
# ..                    ...
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
#
# [1074 rows x 26 columns]

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df
# Out:
#                                               innings   info.city  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...    Canberra
# 0   [{'1st innings': {'team': 'India', 'deliveries...   Bangalore
# 0   [{'1st innings': {'team': 'West Indies', 'deli...  Lauderhill
# 0   [{'1st innings': {'team': 'West Indies', 'deli...    St Lucia
# 0   [{'1st innings': {'team': 'India', 'deliveries...   Bangalore
# ..                                                ...         ...
# 0   [{'1st innings': {'team': 'Australia', 'delive...         NaN
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...    Auckland
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...    Trinidad
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...      Nagpur
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...         NaN
#
#       info.dates info.gender info.match_type info.outcome.winner  info.overs  \
# 0   [2020-02-26]      female             T20            Pakistan          20
# 0   [2016-03-15]      female             T20               India          20
# 0   [2019-08-03]        male             T20               India          20
# 0   [2012-03-27]        male             T20           Australia          20
# 0   [2017-02-01]        male             T20               India          20
# ..           ...         ...             ...                 ...         ...
# 0   [2017-02-17]      female             T20           Australia          20
# 0   [2012-02-11]        male             T20         New Zealand          20
# 0   [2017-04-01]        male             T20         West Indies          20
# 0   [2016-03-08]        male             T20         Afghanistan          20
# 0   [2009-11-12]        male             T20            Pakistan          20
#
#    info.player_of_match                info.teams info.toss.decision  \
# 0        [Javeria Khan]   [Pakistan, West Indies]                bat
# 0              [H Kaur]       [India, Bangladesh]              field
# 0            [NA Saini]      [India, West Indies]              field
# 0           [SR Watson]  [West Indies, Australia]                bat
# 0           [YS Chahal]          [India, England]              field
# ..                  ...                       ...                ...
# 0          [EJ Villani]  [Australia, New Zealand]              field
# 0          [MJ Guptill]   [New Zealand, Zimbabwe]                bat
# 0             [E Lewis]   [West Indies, Pakistan]                bat
# 0    [Mohammad Shahzad]   [Afghanistan, Scotland]                bat
# 0         [Imran Nazir]   [New Zealand, Pakistan]              field
#
#    info.toss.winner                    info.umpires  \
# 0       West Indies          [CA Polosak, S George]
# 0        Bangladesh      [Aleem Dar, REJ Martinesz]
# 0             India       [N Duguid, GO Brathwaite]
# 0       West Indies        [GO Brathwaite, PJ Nero]
# 0           England     [AK Chaudhary, Nitin Menon]
# ..              ...                             ...
# 0       New Zealand           [GA Abood, SAJ Craig]
# 0          Zimbabwe          [GAV Baxter, BG Frost]
# 0          Pakistan      [GO Brathwaite, LS Reifer]
# 0       Afghanistan     [M Erasmus, RK Illingworth]
# 0       New Zealand  [Nadeem Ghauri, Zameer Haider]
#
#                                            info.venue  match_id
# 0                                         Manuka Oval         1
# 0                               M Chinnaswamy Stadium         2
# 0   Central Broward Regional Park Stadium Turf Ground         3
# 0                      Beausejour Stadium, Gros Islet         4
# 0                               M Chinnaswamy Stadium         5
# ..                                                ...       ...
# 0                            Melbourne Cricket Ground      1070
# 0                                           Eden Park      1071
# 0                    Queen's Park Oval, Port of Spain      1072
# 0        Vidarbha Cricket Association Stadium, Jamtha      1073
# 0                 Dubai International Cricket Stadium      1074
#
# [1074 rows x 14 columns]

# %%
final_df['info.gender'].value_counts()
# Out:
# male      737
# female    337
# Name: info.gender, dtype: int64

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
# /Users/samruddhikale/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                               innings   info.city  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...  Lauderhill
# 0   [{'1st innings': {'team': 'West Indies', 'deli...    St Lucia
# 0   [{'1st innings': {'team': 'India', 'deliveries...   Bangalore
# 0   [{'1st innings': {'team': 'England', 'deliveri...  Nottingham
# 0   [{'1st innings': {'team': 'South Africa', 'del...   Cape Town
# ..                                                ...         ...
# 0   [{'1st innings': {'team': 'Singapore', 'delive...   Singapore
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...    Auckland
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...    Trinidad
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...      Nagpur
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...         NaN
#
#       info.dates info.match_type info.outcome.winner  info.overs  \
# 0   [2019-08-03]             T20               India          20
# 0   [2012-03-27]             T20           Australia          20
# 0   [2017-02-01]             T20               India          20
# 0   [2009-06-11]             T20        South Africa          20
# 0   [2020-12-01]             T20             England          20
# ..           ...             ...                 ...         ...
# 0   [2019-07-28]             T20           Singapore          20
# 0   [2012-02-11]             T20         New Zealand          20
# 0   [2017-04-01]             T20         West Indies          20
# 0   [2016-03-08]             T20         Afghanistan          20
# 0   [2009-11-12]             T20            Pakistan          20
#
#    info.player_of_match                info.teams info.toss.decision  \
# 0            [NA Saini]      [India, West Indies]              field
# 0           [SR Watson]  [West Indies, Australia]                bat
# 0           [YS Chahal]          [India, England]              field
# 0           [JH Kallis]   [England, South Africa]                bat
# 0            [DJ Malan]   [South Africa, England]                bat
# ..                  ...                       ...                ...
# 0            [TH David]        [Singapore, Nepal]                bat
# 0          [MJ Guptill]   [New Zealand, Zimbabwe]                bat
# 0             [E Lewis]   [West Indies, Pakistan]                bat
# 0    [Mohammad Shahzad]   [Afghanistan, Scotland]                bat
# 0         [Imran Nazir]   [New Zealand, Pakistan]              field
#
#    info.toss.winner                    info.umpires  \
# 0             India       [N Duguid, GO Brathwaite]
# 0       West Indies        [GO Brathwaite, PJ Nero]
# 0           England     [AK Chaudhary, Nitin Menon]
# 0           England             [SJ Davis, AL Hill]
# 0      South Africa            [A Paleker, BP Jele]
# ..              ...                             ...
# 0         Singapore        [V Kalidas, Tabarak Dar]
# 0          Zimbabwe          [GAV Baxter, BG Frost]
# 0          Pakistan      [GO Brathwaite, LS Reifer]
# 0       Afghanistan     [M Erasmus, RK Illingworth]
# 0       New Zealand  [Nadeem Ghauri, Zameer Haider]
#
#                                            info.venue  match_id
# 0   Central Broward Regional Park Stadium Turf Ground         3
# 0                      Beausejour Stadium, Gros Islet         4
# 0                               M Chinnaswamy Stadium         5
# 0                                        Trent Bridge         6
# 0                                            Newlands         7
# ..                                                ...       ...
# 0                           Indian Association Ground      1069
# 0                                           Eden Park      1071
# 0                    Queen's Park Oval, Port of Spain      1072
# 0        Vidarbha Cricket Association Stadium, Jamtha      1073
# 0                 Dubai International Cricket Stadium      1074
#
# [737 rows x 13 columns]

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    737
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    737
# Name: info.overs, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df
# Out:
#                                               innings   info.city  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...  Lauderhill
# 0   [{'1st innings': {'team': 'West Indies', 'deli...    St Lucia
# 0   [{'1st innings': {'team': 'India', 'deliveries...   Bangalore
# 0   [{'1st innings': {'team': 'England', 'deliveri...  Nottingham
# 0   [{'1st innings': {'team': 'South Africa', 'del...   Cape Town
# ..                                                ...         ...
# 0   [{'1st innings': {'team': 'Singapore', 'delive...   Singapore
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...    Auckland
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...    Trinidad
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...      Nagpur
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...         NaN
#
#       info.dates info.outcome.winner info.player_of_match  \
# 0   [2019-08-03]               India           [NA Saini]
# 0   [2012-03-27]           Australia          [SR Watson]
# 0   [2017-02-01]               India          [YS Chahal]
# 0   [2009-06-11]        South Africa          [JH Kallis]
# 0   [2020-12-01]             England           [DJ Malan]
# ..           ...                 ...                  ...
# 0   [2019-07-28]           Singapore           [TH David]
# 0   [2012-02-11]         New Zealand         [MJ Guptill]
# 0   [2017-04-01]         West Indies            [E Lewis]
# 0   [2016-03-08]         Afghanistan   [Mohammad Shahzad]
# 0   [2009-11-12]            Pakistan        [Imran Nazir]
#
#                   info.teams info.toss.decision info.toss.winner  \
# 0       [India, West Indies]              field            India
# 0   [West Indies, Australia]                bat      West Indies
# 0           [India, England]              field          England
# 0    [England, South Africa]                bat          England
# 0    [South Africa, England]                bat     South Africa
# ..                       ...                ...              ...
# 0         [Singapore, Nepal]                bat        Singapore
# 0    [New Zealand, Zimbabwe]                bat         Zimbabwe
# 0    [West Indies, Pakistan]                bat         Pakistan
# 0    [Afghanistan, Scotland]                bat      Afghanistan
# 0    [New Zealand, Pakistan]              field      New Zealand
#
#                       info.umpires  \
# 0        [N Duguid, GO Brathwaite]
# 0         [GO Brathwaite, PJ Nero]
# 0      [AK Chaudhary, Nitin Menon]
# 0              [SJ Davis, AL Hill]
# 0             [A Paleker, BP Jele]
# ..                             ...
# 0         [V Kalidas, Tabarak Dar]
# 0           [GAV Baxter, BG Frost]
# 0       [GO Brathwaite, LS Reifer]
# 0      [M Erasmus, RK Illingworth]
# 0   [Nadeem Ghauri, Zameer Haider]
#
#                                            info.venue  match_id
# 0   Central Broward Regional Park Stadium Turf Ground         3
# 0                      Beausejour Stadium, Gros Islet         4
# 0                               M Chinnaswamy Stadium         5
# 0                                        Trent Bridge         6
# 0                                            Newlands         7
# ..                                                ...       ...
# 0                           Indian Association Ground      1069
# 0                                           Eden Park      1071
# 0                    Queen's Park Oval, Port of Spain      1072
# 0        Vidarbha Cricket Association Stadium, Jamtha      1073
# 0                 Dubai International Cricket Stadium      1074
#
# [737 rows x 11 columns]

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
#matches=pickle.load(open('dataset_level1.pkl','rb'))
matches
# Out:
#                                               innings   info.city  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...  Lauderhill
# 0   [{'1st innings': {'team': 'West Indies', 'deli...    St Lucia
# 0   [{'1st innings': {'team': 'India', 'deliveries...   Bangalore
# 0   [{'1st innings': {'team': 'England', 'deliveri...  Nottingham
# 0   [{'1st innings': {'team': 'South Africa', 'del...   Cape Town
# ..                                                ...         ...
# 0   [{'1st innings': {'team': 'Singapore', 'delive...   Singapore
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...    Auckland
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...    Trinidad
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...      Nagpur
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...         NaN
#
#       info.dates info.outcome.winner info.player_of_match  \
# 0   [2019-08-03]               India           [NA Saini]
# 0   [2012-03-27]           Australia          [SR Watson]
# 0   [2017-02-01]               India          [YS Chahal]
# 0   [2009-06-11]        South Africa          [JH Kallis]
# 0   [2020-12-01]             England           [DJ Malan]
# ..           ...                 ...                  ...
# 0   [2019-07-28]           Singapore           [TH David]
# 0   [2012-02-11]         New Zealand         [MJ Guptill]
# 0   [2017-04-01]         West Indies            [E Lewis]
# 0   [2016-03-08]         Afghanistan   [Mohammad Shahzad]
# 0   [2009-11-12]            Pakistan        [Imran Nazir]
#
#                   info.teams info.toss.decision info.toss.winner  \
# 0       [India, West Indies]              field            India
# 0   [West Indies, Australia]                bat      West Indies
# 0           [India, England]              field          England
# 0    [England, South Africa]                bat          England
# 0    [South Africa, England]                bat     South Africa
# ..                       ...                ...              ...
# 0         [Singapore, Nepal]                bat        Singapore
# 0    [New Zealand, Zimbabwe]                bat         Zimbabwe
# 0    [West Indies, Pakistan]                bat         Pakistan
# 0    [Afghanistan, Scotland]                bat      Afghanistan
# 0    [New Zealand, Pakistan]              field      New Zealand
#
#                       info.umpires  \
# 0        [N Duguid, GO Brathwaite]
# 0         [GO Brathwaite, PJ Nero]
# 0      [AK Chaudhary, Nitin Menon]
# 0              [SJ Davis, AL Hill]
# 0             [A Paleker, BP Jele]
# ..                             ...
# 0         [V Kalidas, Tabarak Dar]
# 0           [GAV Baxter, BG Frost]
# 0       [GO Brathwaite, LS Reifer]
# 0      [M Erasmus, RK Illingworth]
# 0   [Nadeem Ghauri, Zameer Haider]
#
#                                            info.venue  match_id
# 0   Central Broward Regional Park Stadium Turf Ground         3
# 0                      Beausejour Stadium, Gros Islet         4
# 0                               M Chinnaswamy Stadium         5
# 0                                        Trent Bridge         6
# 0                                            Newlands         7
# ..                                                ...       ...
# 0                           Indian Association Ground      1069
# 0                                           Eden Park      1071
# 0                    Queen's Park Oval, Port of Spain      1072
# 0        Vidarbha Cricket Association Stadium, Jamtha      1073
# 0                 Dubai International Cricket Stadium      1074
#
# [737 rows x 11 columns]

# %%
#matches = pickle.load(open('dataset_level1.pkl','rb'))
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
matches
# Out:
#                                               innings   info.city  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...  Lauderhill
# 0   [{'1st innings': {'team': 'West Indies', 'deli...    St Lucia
# 0   [{'1st innings': {'team': 'India', 'deliveries...   Bangalore
# 0   [{'1st innings': {'team': 'England', 'deliveri...  Nottingham
# 0   [{'1st innings': {'team': 'South Africa', 'del...   Cape Town
# ..                                                ...         ...
# 0   [{'1st innings': {'team': 'Singapore', 'delive...   Singapore
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...    Auckland
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...    Trinidad
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...      Nagpur
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...         NaN
#
#       info.dates info.outcome.winner info.player_of_match  \
# 0   [2019-08-03]               India           [NA Saini]
# 0   [2012-03-27]           Australia          [SR Watson]
# 0   [2017-02-01]               India          [YS Chahal]
# 0   [2009-06-11]        South Africa          [JH Kallis]
# 0   [2020-12-01]             England           [DJ Malan]
# ..           ...                 ...                  ...
# 0   [2019-07-28]           Singapore           [TH David]
# 0   [2012-02-11]         New Zealand         [MJ Guptill]
# 0   [2017-04-01]         West Indies            [E Lewis]
# 0   [2016-03-08]         Afghanistan   [Mohammad Shahzad]
# 0   [2009-11-12]            Pakistan        [Imran Nazir]
#
#                   info.teams info.toss.decision info.toss.winner  \
# 0       [India, West Indies]              field            India
# 0   [West Indies, Australia]                bat      West Indies
# 0           [India, England]              field          England
# 0    [England, South Africa]                bat          England
# 0    [South Africa, England]                bat     South Africa
# ..                       ...                ...              ...
# 0         [Singapore, Nepal]                bat        Singapore
# 0    [New Zealand, Zimbabwe]                bat         Zimbabwe
# 0    [West Indies, Pakistan]                bat         Pakistan
# 0    [Afghanistan, Scotland]                bat      Afghanistan
# 0    [New Zealand, Pakistan]              field      New Zealand
#
#                       info.umpires  \
# 0        [N Duguid, GO Brathwaite]
# 0         [GO Brathwaite, PJ Nero]
# 0      [AK Chaudhary, Nitin Menon]
# 0              [SJ Davis, AL Hill]
# 0             [A Paleker, BP Jele]
# ..                             ...
# 0         [V Kalidas, Tabarak Dar]
# 0           [GAV Baxter, BG Frost]
# 0       [GO Brathwaite, LS Reifer]
# 0      [M Erasmus, RK Illingworth]
# 0   [Nadeem Ghauri, Zameer Haider]
#
#                                            info.venue  match_id
# 0   Central Broward Regional Park Stadium Turf Ground         3
# 0                      Beausejour Stadium, Gros Islet         4
# 0                               M Chinnaswamy Stadium         5
# 0                                        Trent Bridge         6
# 0                                            Newlands         7
# ..                                                ...       ...
# 0                           Indian Association Ground      1069
# 0                                           Eden Park      1071
# 0                    Queen's Park Oval, Port of Spain      1072
# 0        Vidarbha Cricket Association Stadium, Jamtha      1073
# 0                 Dubai International Cricket Stadium      1074
#
# [737 rows x 11 columns]

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)

# %%
delivery_df
# Out:
#      match_id                    teams batting_team  ball        batsman  \
# 0           2     [India, West Indies]  West Indies   0.1    JD Campbell
# 1           2     [India, West Indies]  West Indies   0.2    JD Campbell
# 2           2     [India, West Indies]  West Indies   0.3       N Pooran
# 3           2     [India, West Indies]  West Indies   0.4       N Pooran
# 4           2     [India, West Indies]  West Indies   0.5        E Lewis
# ..        ...                      ...          ...   ...            ...
# 117       738  [New Zealand, Pakistan]     Pakistan  19.2  Sohail Tanvir
# 118       738  [New Zealand, Pakistan]     Pakistan  19.3  Sohail Tanvir
# 119       738  [New Zealand, Pakistan]     Pakistan  19.4   Abdul Razzaq
# 120       738  [New Zealand, Pakistan]     Pakistan  19.5  Mohammad Amir
# 121       738  [New Zealand, Pakistan]     Pakistan  19.6  Mohammad Amir
#
#                 bowler  runs player_dismissed        city  \
# 0    Washington Sundar     0                0  Lauderhill
# 1    Washington Sundar     0      JD Campbell  Lauderhill
# 2    Washington Sundar     0                0  Lauderhill
# 3    Washington Sundar     1                0  Lauderhill
# 4    Washington Sundar     0                0  Lauderhill
# ..                 ...   ...              ...         ...
# 117         TG Southee     6                0         NaN
# 118         TG Southee     0    Sohail Tanvir         NaN
# 119         TG Southee     1                0         NaN
# 120         TG Southee     2                0         NaN
# 121         TG Southee     0    Mohammad Amir         NaN
#
#                                                  venue
# 0    Central Broward Regional Park Stadium Turf Ground
# 1    Central Broward Regional Park Stadium Turf Ground
# 2    Central Broward Regional Park Stadium Turf Ground
# 3    Central Broward Regional Park Stadium Turf Ground
# 4    Central Broward Regional Park Stadium Turf Ground
# ..                                                 ...
# 117                Dubai International Cricket Stadium
# 118                Dubai International Cricket Stadium
# 119                Dubai International Cricket Stadium
# 120                Dubai International Cricket Stadium
# 121                Dubai International Cricket Stadium
#
# [87856 rows x 10 columns]

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#      match_id                    teams batting_team  ball        batsman  \
# 0           2     [India, West Indies]  West Indies   0.1    JD Campbell
# 1           2     [India, West Indies]  West Indies   0.2    JD Campbell
# 2           2     [India, West Indies]  West Indies   0.3       N Pooran
# 3           2     [India, West Indies]  West Indies   0.4       N Pooran
# 4           2     [India, West Indies]  West Indies   0.5        E Lewis
# ..        ...                      ...          ...   ...            ...
# 117       738  [New Zealand, Pakistan]     Pakistan  19.2  Sohail Tanvir
# 118       738  [New Zealand, Pakistan]     Pakistan  19.3  Sohail Tanvir
# 119       738  [New Zealand, Pakistan]     Pakistan  19.4   Abdul Razzaq
# 120       738  [New Zealand, Pakistan]     Pakistan  19.5  Mohammad Amir
# 121       738  [New Zealand, Pakistan]     Pakistan  19.6  Mohammad Amir
#
#                 bowler  runs player_dismissed        city  \
# 0    Washington Sundar     0                0  Lauderhill
# 1    Washington Sundar     0      JD Campbell  Lauderhill
# 2    Washington Sundar     0                0  Lauderhill
# 3    Washington Sundar     1                0  Lauderhill
# 4    Washington Sundar     0                0  Lauderhill
# ..                 ...   ...              ...         ...
# 117         TG Southee     6                0         NaN
# 118         TG Southee     0    Sohail Tanvir         NaN
# 119         TG Southee     1                0         NaN
# 120         TG Southee     2                0         NaN
# 121         TG Southee     0    Mohammad Amir         NaN
#
#                                                  venue bowling_team
# 0    Central Broward Regional Park Stadium Turf Ground        India
# 1    Central Broward Regional Park Stadium Turf Ground        India
# 2    Central Broward Regional Park Stadium Turf Ground        India
# 3    Central Broward Regional Park Stadium Turf Ground        India
# 4    Central Broward Regional Park Stadium Turf Ground        India
# ..                                                 ...          ...
# 117                Dubai International Cricket Stadium  New Zealand
# 118                Dubai International Cricket Stadium  New Zealand
# 119                Dubai International Cricket Stadium  New Zealand
# 120                Dubai International Cricket Stadium  New Zealand
# 121                Dubai International Cricket Stadium  New Zealand
#
# [87856 rows x 11 columns]

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df
# Out:
#      match_id batting_team  ball        batsman             bowler  runs  \
# 0           2  West Indies   0.1    JD Campbell  Washington Sundar     0
# 1           2  West Indies   0.2    JD Campbell  Washington Sundar     0
# 2           2  West Indies   0.3       N Pooran  Washington Sundar     0
# 3           2  West Indies   0.4       N Pooran  Washington Sundar     1
# 4           2  West Indies   0.5        E Lewis  Washington Sundar     0
# ..        ...          ...   ...            ...                ...   ...
# 117       738     Pakistan  19.2  Sohail Tanvir         TG Southee     6
# 118       738     Pakistan  19.3  Sohail Tanvir         TG Southee     0
# 119       738     Pakistan  19.4   Abdul Razzaq         TG Southee     1
# 120       738     Pakistan  19.5  Mohammad Amir         TG Southee     2
# 121       738     Pakistan  19.6  Mohammad Amir         TG Southee     0
#
#     player_dismissed        city  \
# 0                  0  Lauderhill
# 1        JD Campbell  Lauderhill
# 2                  0  Lauderhill
# 3                  0  Lauderhill
# 4                  0  Lauderhill
# ..               ...         ...
# 117                0         NaN
# 118    Sohail Tanvir         NaN
# 119                0         NaN
# 120                0         NaN
# 121    Mohammad Amir         NaN
#
#                                                  venue bowling_team
# 0    Central Broward Regional Park Stadium Turf Ground        India
# 1    Central Broward Regional Park Stadium Turf Ground        India
# 2    Central Broward Regional Park Stadium Turf Ground        India
# 3    Central Broward Regional Park Stadium Turf Ground        India
# 4    Central Broward Regional Park Stadium Turf Ground        India
# ..                                                 ...          ...
# 117                Dubai International Cricket Stadium  New Zealand
# 118                Dubai International Cricket Stadium  New Zealand
# 119                Dubai International Cricket Stadium  New Zealand
# 120                Dubai International Cricket Stadium  New Zealand
# 121                Dubai International Cricket Stadium  New Zealand
#
# [87856 rows x 10 columns]

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['West Indies', 'India', 'England', 'South Africa', 'Netherlands',
#        'New Zealand', 'Afghanistan', 'Pakistan', 'Kenya', 'Australia',
#        'Malaysia', 'Ireland', 'Zimbabwe', 'Nigeria', 'Singapore', 'Nepal',
#        'Bangladesh', 'Vanuatu', 'Hong Kong', 'United Arab Emirates',
#        'Thailand', 'Canada', 'Sri Lanka', 'Papua New Guinea', 'Spain',
#        'Scotland', 'Belgium', 'Oman', 'Kuwait', 'Jersey', 'Gibraltar',
#        'Denmark', 'Cayman Islands', 'United States of America',
#        'Philippines', 'Ghana', 'Guernsey', 'Namibia', 'Bermuda', 'Qatar',
#        'Germany', 'Botswana', 'Italy', 'Romania', 'Norway', 'Isle of Man',
#        'Uganda', 'Maldives', 'Bulgaria', 'Iran'], dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball        batsman             bowler  runs  \
# 0           2  West Indies   0.1    JD Campbell  Washington Sundar     0
# 1           2  West Indies   0.2    JD Campbell  Washington Sundar     0
# 2           2  West Indies   0.3       N Pooran  Washington Sundar     0
# 3           2  West Indies   0.4       N Pooran  Washington Sundar     1
# 4           2  West Indies   0.5        E Lewis  Washington Sundar     0
# ..        ...          ...   ...            ...                ...   ...
# 117       738     Pakistan  19.2  Sohail Tanvir         TG Southee     6
# 118       738     Pakistan  19.3  Sohail Tanvir         TG Southee     0
# 119       738     Pakistan  19.4   Abdul Razzaq         TG Southee     1
# 120       738     Pakistan  19.5  Mohammad Amir         TG Southee     2
# 121       738     Pakistan  19.6  Mohammad Amir         TG Southee     0
#
#     player_dismissed        city  \
# 0                  0  Lauderhill
# 1        JD Campbell  Lauderhill
# 2                  0  Lauderhill
# 3                  0  Lauderhill
# 4                  0  Lauderhill
# ..               ...         ...
# 117                0         NaN
# 118    Sohail Tanvir         NaN
# 119                0         NaN
# 120                0         NaN
# 121    Mohammad Amir         NaN
#
#                                                  venue bowling_team
# 0    Central Broward Regional Park Stadium Turf Ground        India
# 1    Central Broward Regional Park Stadium Turf Ground        India
# 2    Central Broward Regional Park Stadium Turf Ground        India
# 3    Central Broward Regional Park Stadium Turf Ground        India
# 4    Central Broward Regional Park Stadium Turf Ground        India
# ..                                                 ...          ...
# 117                Dubai International Cricket Stadium  New Zealand
# 118                Dubai International Cricket Stadium  New Zealand
# 119                Dubai International Cricket Stadium  New Zealand
# 120                Dubai International Cricket Stadium  New Zealand
# 121                Dubai International Cricket Stadium  New Zealand
#
# [47174 rows x 10 columns]

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  West Indies        India   0.1     0                0
# 1           2  West Indies        India   0.2     0      JD Campbell
# 2           2  West Indies        India   0.3     0                0
# 3           2  West Indies        India   0.4     1                0
# 4           2  West Indies        India   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 117       738     Pakistan  New Zealand  19.2     6                0
# 118       738     Pakistan  New Zealand  19.3     0    Sohail Tanvir
# 119       738     Pakistan  New Zealand  19.4     1                0
# 120       738     Pakistan  New Zealand  19.5     2                0
# 121       738     Pakistan  New Zealand  19.6     0    Mohammad Amir
#
#            city                                              venue
# 0    Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 1    Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 2    Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 3    Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 4    Lauderhill  Central Broward Regional Park Stadium Turf Ground
# ..          ...                                                ...
# 117         NaN                Dubai International Cricket Stadium
# 118         NaN                Dubai International Cricket Stadium
# 119         NaN                Dubai International Cricket Stadium
# 120         NaN                Dubai International Cricket Stadium
# 121         NaN                Dubai International Cricket Stadium
#
# [47174 rows x 8 columns]

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))

# %%
output[output['city'].isnull()]['venue'].value_counts()

# %%
x = np.where(output['city'].isnull(), output['venue'].str.split().apply(lambda x:x[0]), output['city'])

# %%
output['city'] = x

# %%
output.isnull().sum()

# %%
output.drop(columns=['venue'],inplace=True)

# %%
output

# %%
total_df = output.groupby('match_id').sum()['runs'].reset_index()
output = output.merge(total_df,on='match_id')

# %%
output

# %%
output['current_score'] = output.groupby('match_id').cumsum()['runs_x']

# %%
output['over'] = output['ball'].apply(lambda x:str(x).split(".")[0])
output['ball_no'] = output['ball'].apply(lambda x:str(x).split(".")[1])

# %%
output['balls_bowled'] = (output['over'].astype('int')*6) + output['ball_no'].astype('int')

# %%
output['crr'] = round((output['current_score']*6)/output['balls_bowled'],2)

# %%
output['player_dismissed'] = output['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
output['player_dismissed'] = output['player_dismissed'].astype('int')
output['player_dismissed'] = output.groupby('match_id').cumsum()['player_dismissed']
output['wickets_left'] = 10 - output['player_dismissed']

# %%
final_df = output[['match_id','batting_team','bowling_team','runs_x','current_score','balls_bowled','wickets_left','crr','city','runs_y']]

# %%
final_df

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df['balls_left'] = 120 - final_df['balls_bowled']
final_df['balls_left'] = final_df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
final_df['crr'] = round((final_df['current_score']*6)/final_df['balls_bowled'],2)

# %%
final_df

# %%
final_df.drop(columns=['balls_bowled'],inplace=True)

# %%
groups = final_df.groupby('match_id')

# %%
match_ids = final_df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs_x'].values.tolist())

# %%
final_df['last_five'] = last_five

# %%
final_df

# %%
final_df.dropna(inplace=True)

# %%
final_df

# %%
eligible_cities = final_df['city'].value_counts()[final_df['city'].value_counts() > 600].index.tolist()
final_df = final_df[final_df['city'].isin(eligible_cities)]

# %%
X = final_df.drop(columns=['match_id','runs_x','runs_y'])
y = final_df['runs_y']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_test

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))

# %%
teams
